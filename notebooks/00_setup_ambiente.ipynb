-- %%
CREATE SCHEMA IF NOT EXISTS workspace.bronze
COMMENT 'Camada de dados brutos do projeto Olist';

CREATE SCHEMA IF NOT EXISTS workspace.silver
COMMENT 'Camada de dados tratados e padronizados do projeto Olist';

CREATE SCHEMA IF NOT EXISTS workspace.gold
COMMENT 'Camada de dados analiticos do projeto Olist';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE VOLUME IF NOT EXISTS workspace.bronze.olist_raw
COMMENT 'Arquivos CSV originais do dataset Brazilian E-Commerce da Olist';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
